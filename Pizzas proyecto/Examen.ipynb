# %%
import pandas as pd

# %%
# Load of all .csv
df_ubereats_centro = pd.read_csv(r'csv/ubereats-pizza-centro.csv')
df_ubereats_alamos = pd.read_csv(r'csv/ubereats-pizza-alamos.csv')
df_ubereats_juriquilla = pd.read_csv(r'csv/ubereats-pizza-juriquilla.csv')
df_ubereats_milenio = pd.read_csv(r'csv/ubereats-pizza-milenio.csv')
df_ubereats_refugio = pd.read_csv(r'csv/ubereats-pizza-refugio.csv')

df_ubereats_balvanera = pd.read_csv(r'csv/ubereats-pizza-balvanera.csv')
df_ubereats_campanario = pd.read_csv(r'csv/ubereats-pizza-campanario.csv')
df_ubereats_cerritocolorado = pd.read_csv(r'csv/ubereats-pizza-cerritocolorado.csv')
df_ubereats_cimatario = pd.read_csv(r'csv/ubereats-pizza-cimatario.csv')
df_ubereats_el_pueblito = pd.read_csv(r'csv/ubereats-pizza-el-pueblito.csv')

df_rappi_centro = pd.read_csv(r'csv/rappi-pizza-centro.csv')
df_rappi_alamos = pd.read_csv(r'csv/rappi-pizza-alamos.csv')
df_rappi_juriquilla = pd.read_csv(r'csv/rappi-pizza-juriquilla.csv')
df_rappi_milenio = pd.read_csv(r'csv/rappi-pizza-milenio.csv')
df_rappi_refugio = pd.read_csv(r'csv/rappi-pizza-refugio.csv')

df_rappi_balvanera = pd.read_csv(r'csv/rappi-pizza-balvanera.csv')
df_rappi_campanario = pd.read_csv(r'csv/rappi-pizza-campanario.csv')
df_rappi_cerritocolorado = pd.read_csv(r'csv/rappi-pizza-cerritocolorado.csv')
df_rappi_cimatario = pd.read_csv(r'csv/rappi-pizza-cimatario.csv')
df_rappi_el_pueblito = pd.read_csv(r'csv/rappi-pizza-el-pueblito.csv')

frames = [
    df_ubereats_centro,
    df_ubereats_alamos, 
    df_ubereats_juriquilla, 
    df_ubereats_milenio, 
    df_ubereats_refugio, 
    df_ubereats_balvanera, 
    df_ubereats_campanario, 
    df_ubereats_cerritocolorado, 
    df_ubereats_cimatario, 
    df_ubereats_el_pueblito, 
    df_rappi_centro, 
    df_rappi_alamos, 
    df_rappi_juriquilla, 
    df_rappi_milenio, 
    df_rappi_refugio, 
    df_rappi_balvanera, 
    df_rappi_campanario, 
    df_rappi_cerritocolorado, 
    df_rappi_cimatario, 
    df_rappi_el_pueblito]

# We concat all frames and ignore the current index to generate a new one
df = pd.concat(frames, ignore_index=True)

# %%
print('Size of the df: {} items'.format(df.count()['name']))
# Out:
# Size of the df: 52649 items

# %%
# Remove MX$ from price-food
df['price-food'] = df['price-food'].apply(lambda x: (float(x[3:] if x[0] == 'M' else x[1:]) if not isinstance(x, int) else float(x)) if not isinstance(x, float) else x)
df.loc[:,['name','name-food','price-food','colonia', 'rating']]
# Out:
#                              name                name-food  price-food  \
# 0                         Di Vino    Lasagna a la boloñesa       201.5
# 1             Diktatur (Guerrero)        Molletes de jamón        60.0
# 2       The Zone Bread and Coffee                   Frappé        50.0
# 3      Papa John's Pizza Jardines                Hawaiiana       249.0
# 4           Micaela Cocina & Café                De panela       175.0
# ...                           ...                      ...         ...
# 52680               Trapani Pizza  Sangria Señorial 355 ml        25.0
# 52681            Il Pizzaiolo Qro        Pasta Amatriciana       119.0
# 52682                  Pizza Riko           Dedos de Queso        97.0
# 52683                 Estacion 19               Cappuccino        52.0
# 52684  Nápoles Artesanal Pizzería           Pizza Capresse       245.0
#
#         colonia  rating
# 0           NaN     4.5
# 1           NaN     4.9
# 2           NaN     4.8
# ...

# %%
modeMenu = df.loc[df['name-food'] == df['name-food'].mode()[0]]

# %%
print('Menú:')
modeMenu.loc[:,['name','name-food','price-food','colonia','rating']]
# Out:
# Menú:
#                        name       name-food price-food   colonia  rating
# 13                  Di Vino  Pizza Hawaiana    $199.00       NaN     4.5
# 37                Lynchburg  Pizza Hawaiana    $179.00       NaN     NaN
# 48           Rayuela Pizzas  Pizza Hawaiana    $100.00       NaN     4.9
# 936             Sinatra 351  Pizza Hawaiana    $179.00       NaN     NaN
# 1301              Dio Pizza  Pizza Hawaiana    $134.80       NaN     3.9
# ...                     ...             ...        ...       ...     ...
# 38587          Pizza & More  Pizza Hawaiana        169  pueblito     NaN
# 38629  Mariscos El Naufrago  Pizza Hawaiana        183  pueblito     NaN
# 38775      Piacere Italiano  Pizza Hawaiana        165  pueblito     NaN
# 38841      Abuelita´S Pizza  Pizza Hawaiana        248  pueblito     4.7
# 38906    Mi Piace Pizza Qro  Pizza Hawaiana        125  pueblito     NaN
#
# [222 rows x 5 columns]

# %%
maxPizza = df.loc[df['rating'] == dfRe['rating'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                               name                name-food  price-food  \
# 2        The Zone Bread and Coffee                   Frappé        50.0
# 4            Micaela Cocina & Café                De panela       175.0
# 15     Sushi Roll (Punta Victoria)               Crush Roll       181.0
# 16       The Zone Bread and Coffee            Matcha grande        60.0
# 22       The Zone Bread and Coffee            Doña especial        85.0
# ...                            ...                      ...         ...
# 38889                Trapani Pizza        Pizza Vegetariana       150.0
# 38898                 Zapata Pizza               Sprite 2 L        48.0
# 38900                Trapani Pizza   Combo 2 Pizzas Grandes       268.0
# 38905                    Piu Pizza             Pizza Salami       120.0
# 38907                Trapani Pizza  Sangria Señorial 355 ml        25.0
#
#        rating
# 2         4.8
# 4         4.8
# 15        4.8
# ...

# %%
# Get all "alamos" dataframes
dfAlamos = df[df['colonia'].str.contains("alamos", na=False, case=False)]
dfAlamos.reset_index(drop=True, inplace=True)
# dfAlamos.loc[:,['name','name-food','price-food','colonia']]
modeA = dfAlamos.loc[df['name-food'] == dfAlamos['name-food'].mode()[0]]

print('The pizzas with the mode price are:')
modeA.loc[:,['name','name-food','price-food','colonia','rating','evals']]
# Out:
# The pizzas with the mode price are:
#                                    name  \
# 13              Aldo´s Pizza El Marqués
# 37                            Jaguaryou
# 48              Subway (Pza Boulevares)
# 936        Circle K 🛒 (Que Cerrito 967)
# 1301                      Güero's Pizza
# 1613  Sushi Roll (Boulevares Querétaro)
# 1919            Subway (Pza Boulevares)
# 2322       Circle K 🛒 (Que Cerrito 967)
# 2378     Los Dogos (Puerta La Victoria)
# 2523                            Manceba
# 2668            Subway (Pza Boulevares)
# 2693  Sushi Roll (Boulevares Querétaro)
# 2724                         Che-Chelas
# 2784                  Filemón Querétaro
# 2875                         La Campana
# 3280                         Che-Chelas
# 3510      Tacos Pampas (Constituyentes)
# 3637             Diktatur (Universidad)
# 3865                            Nambila
# 3992   Nuriko Sushi Express Universidad
# 3994                            Di Vino
# ...

# %%
minPizza = dfAlamos.loc[dfAlamos['price-food'] == dfAlamos['price-food'].min()]

print('The pizzas with the lower price are:')
minPizza.loc[:,['name','name-food','price-food']]
# Out:
# The pizzas with the lower price are:
#                                  name                             name-food  \
# 505  Nuriko Sushi Express Universidad  ¿Para cuántas personas es tu pedido?
#
#      price-food
# 505        0.01

# %%
maxPizza = dfAlamos.loc[dfAlamos['price-food'] == dfAlamos['price-food'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food']]
# Out:
# The pizzas with the greatest price are:
#           name              name-food  price-food
# 1129  La Bocha  Rib Eye Calidad Prime       945.0

# %%
minPizza = dfAlamos.loc[dfAlamos['rating'] == dfAlamos['rating'].min()]

print('The pizzas with the lower price are:')
minPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the lower price are:
#                           name                    name-food  price-food  \
# 75    Domino's Querétaro Arcos                  Pepsi Black        20.0
# 340   Domino's Querétaro Arcos  Arma tu Pizza 1 Ingrediente       144.0
# 344   Domino's Querétaro Arcos                      Mirinda        20.0
# 360   Domino's Querétaro Arcos                      Mirinda        40.0
# 389          Filemón Querétaro                Avocado toast        75.0
# ...                        ...                          ...         ...
# 5146                 Cheese Up             Pizza Choriqueso       155.0
# 5211                 Cheese Up               Pizza Italiana       155.0
# 5215                 Cheese Up           Pizza Carnes Frías       155.0
# 5216                 Cheese Up     Coca-Cola Original 1.5 L        40.0
# 5218                 Cheese Up          Manzana Lift 600 ml        20.0
#
#       rating
# 75       3.9
# 340      3.9
# 344      3.9
# ...

# %%
maxPizza = dfAlamos.loc[dfAlamos['rating'] == dfAlamos['rating'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                                 name                          name-food  \
# 33    La Piccola Trattoria Querétaro                  pera e gorgonzola
# 201   La Piccola Trattoria Querétaro                  pizza fiordilatte
# 342   La Piccola Trattoria Querétaro                   pizza parmigiana
# 463   La Piccola Trattoria Querétaro   pizza pepperoni-pizza margherita
# 486   La Piccola Trattoria Querétaro                   Pasta del giorno
# 645   La Piccola Trattoria Querétaro            pizza provola e salmone
# 704   La Piccola Trattoria Querétaro              Spaghetti al pomodoro
# 1271  La Piccola Trattoria Querétaro                   Salmone al grill
# 1369  La Piccola Trattoria Querétaro              Penne alla sorrentina
# 1390  La Piccola Trattoria Querétaro                  pera e gorgonzola
# 1646  La Piccola Trattoria Querétaro                   pizza margherita
# ...

# %%
import matplotlib.pyplot as plt
plt.subplot(1,2,1)
plt.plot(dfAlamos['price-food'],'ro')

plt.subplot(1,2,2)
plt.plot(dfAlamos['rating'],'ro')

plt.show()

# %%
# Get all "centr0" dataframes
dfCentro = df[df['colonia'].str.contains("centro", na=True, case=False)]
dfCentro.reset_index(drop=True, inplace=True)
# dfAlamos.loc[:,['name','name-food','price-food','colonia']]
modeC = dfCentro.loc[df['name-food'] == dfCentro['name-food'].mode()[0]]

print('The pizzas with the mode price are:')
modeC.loc[:,['name','name-food','price-food','colonia','rating']]
# Out:
# The pizzas with the mode price are:
#                                name                            name-food  \
# 13                          Di Vino                       Pizza Hawaiana
# 37                        Lynchburg                       Pizza Hawaiana
# 48                   Rayuela Pizzas                       Pizza Hawaiana
# 936                     Sinatra 351                       Pizza Hawaiana
# 1301                      Dio Pizza                       Pizza Hawaiana
# 1613            Pizzería Alto Horno                       Pizza Hawaiana
# 1919        Aldo´s Pizza El Marqués                       Pizza Hawaiana
# 2322                 Chihuahuas Bar                       Pizza Hawaiana
# 2378           La Marmota Cimatario                       Pizza Hawaiana
# 2523                   Napoli Pizza                       Pizza Hawaiana
# 2668                    The Factory                       Pizza Hawaiana
# ...

# %%
minPizza = dfCentro.loc[dfCentro['price-food'] == dfCentro['price-food'].min()]

print('The pizzas with the lower price are:')
minPizza.loc[:,['name','name-food','price-food']]
# Out:
# The pizzas with the lower price are:
#                                   name                             name-food  \
# 3990  Nuriko Sushi Express Tecnológico  ¿Para cuántas personas es tu pedido?
#
#       price-food
# 3990        0.01

# %%
maxPizza = dfCentro.loc[dfCentro['price-food'] == dfCentro['price-food'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#              name              name-food  price-food  rating
# 671  Bruno Cucina  Linguini con Langosta      1350.0     4.8

# %%
maxPizza = dfCentro.loc[dfCentro['rating'] == dfCentro['rating'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                                                name                 name-food  \
# 1                               Diktatur (Guerrero)         Molletes de jamón
# 48                                   Rayuela Pizzas            Pizza Hawaiana
# 76                              Diktatur (Guerrero)    Agua de Cebada (450ml)
# 88    Coffee Tree Cinépolis 🛒 (La Victoria Latitud)    Frappé Cookies & Cream
# 117                             Diktatur (Guerrero)   Agua de pepino (450 ml)
# ...                                             ...                       ...
# 4521                            Diktatur (Guerrero)                   Elenita
# 4523                            Diktatur (Guerrero)  Chilaquiles con omelette
# 4532                            Diktatur (Guerrero)       Coca light (355 ml)
# 4655                            Diktatur (Guerrero)                  Granjero
# ...

# %%
import matplotlib.pyplot as plt
plt.subplot(1,2,1)
plt.plot(dfCentro['price-food'],'ro')

plt.subplot(1,2,2)
plt.plot(dfCentro['rating'] ,'ro')

plt.show()

# %%
# Get all "refugio" dataframes
dfRe = df[df['colonia'].str.contains("refugio", na=False, case=False)]
dfRe.reset_index(drop=True, inplace=True)
# dfAlamos.loc[:,['name','name-food','price-food','colonia']]
modeRe = dfRe.loc[df['name-food'] == dfRe['name-food'].mode()[0]]

print('The pizzas with the mode price are:')
modeRe.loc[:,['name','name-food','price-food','colonia','rating','evals']]
# Out:
# The pizzas with the mode price are:
#                                    name                  name-food  \
# 207                          Nuut Grill                   Cabreria
# 411     Cassava Roots (Paseo Queretaro)  N9 snöu white green apple
# 470                 Mac't Fonda Gourmet               Papas bravas
# 783      Los Hijos del Che (El Refugio)               Dogo del mes
# 848   Pizza Industry Gourmet El Refugio        Orden de papas gajo
# 1142      Tentazione Pizzas Artesanales            Pizza Al Pastor
#
#       price-food  colonia  rating evals
# 207        465.0  refugio     NaN   NaN
# 411         48.0  refugio     4.5   -33
# 470         65.0  refugio     NaN   NaN
# 783         88.0  refugio     4.8  -121
# 848         69.0  refugio     4.8   -76
# 1142       220.0  refugio     NaN   NaN

# %%
minPizza = dfRe.loc[dfRe['price-food'] == dfRe['price-food'].min()]

print('The pizzas with the lower price are:')
minPizza.loc[:,['name','name-food','price-food']]
# Out:
# The pizzas with the lower price are:
#                                 name               name-food  price-food
# 510  Cassava Roots (Paseo Queretaro)      Popping boba fresa         8.0
# 633  Cassava Roots (Paseo Queretaro)     Popping boba lychee         8.0
# 888  Cassava Roots (Paseo Queretaro)  Popping boba blueberry         8.0

# %%
maxPizza = dfRe.loc[dfRe['price-food'] == dfRe['price-food'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                                     name  \
# 675  Todo Empanadas El Refugio Queretaro
#
#                                  name-food  price-food  rating
# 675  Ensalada Gaucha Para 20 a 25 Personas       670.0     4.8

# %%
maxPizza = dfRe.loc[dfRe['rating'] == dfRe['rating'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                                      name              name-food  price-food  \
# 0          Los Hijos del Che (El Refugio)  La carismática de res        72.0
# 6       Pizza Industry Gourmet El Refugio                Suprema       239.0
# 10         Los Hijos del Che (El Refugio)                  Papas        46.0
# 11         Los Hijos del Che (El Refugio)    La arrache sencilla        90.0
# 17    Todo Empanadas El Refugio Queretaro       Empanada Norteña        36.0
# ...                                   ...                    ...         ...
# 1295                     Pizzería Al Volo        Victoria 355 ml        50.0
# 1301                     Pizzería Al Volo                  Hawai       187.0
# 1303                     Pizzería Al Volo            Capricciosa       236.0
# 1317                     Pizzería Al Volo     Spaguetti Al Pesto       130.0
# 1321                     Pizzería Al Volo              Siciliana       220.0
#
# ...

# %%
import matplotlib.pyplot as plt
plt.subplot(1,2,1)
plt.plot(dfRe['price-food'],'ro')

plt.subplot(1,2,2)
plt.plot(dfRe['rating'], dfRe['evals'],'ro')

plt.show()

# %%
# Get all "Milenio" dataframes
dfMi = df[df['colonia'].str.contains("Milenio", na=False, case=False)]
dfMi.reset_index(drop=True, inplace=True)
# dfAlamos.loc[:,['name','name-food','price-food','colonia']]
modeMi = dfMi.loc[df['name-food'] == dfMi['name-food'].mode()[0]]

print('The pizzas with the mode price are:')
modeMi.loc[:,['name','name-food','price-food','colonia','rating','evals']]
# Out:
# The pizzas with the mode price are:
#                                      name  \
# 13            El Globo Queretaro Jardines
# 37          Circle K 🛒 (Que Palmas 2 989)
# 48                                Nambila
# 936      Nuriko Sushi Express Universidad
# 1301                             La Bocha
# 1613                  Dozzo Coffee & Eats
# 1919        Ristorante Italiano Brancacci
# 2322              Subway (Cuauhtemoc QRO)
# 2378                             Be Green
# 2523  Gabo´s Pizza & Grill (Popocatépetl)
# 2668     Nuriko Sushi Express Universidad
# 2693                          Sinatra 351
# 2724                               Casual
# 2784         El Comal Antojitos Mexicanos
# 2875        Circle K 🛒 (Que Palmas 2 989)
# 3280                      Pizzeta (Arcos)
# 3510        Tacos Pampas (Constituyentes)
# 3637                  Dozzo Coffee & Eats
# 3865     Nuriko Sushi Express Universidad
# 3992                               Casual
# ...

# %%
minPizzaMi = dfMi.loc[dfMi['price-food'] == dfMi['price-food'].min()]

print('The pizzas with the greatest price are:')
minPizzaMi.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                                   name                             name-food  \
# 1421  Nuriko Sushi Express Universidad  ¿Para cuántas personas es tu pedido?
#
#       price-food  rating
# 1421        0.01     4.5

# %%
maxPizza = dfMi.loc[dfMi['price-food'] == dfMi['price-food'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                                 name                        name-food  \
# 173   Juguetron® 🛒🧸 (Constituyentes)  Set De Juego Monster Dirt Arena
# 1814  Juguetron® 🛒🧸 (Constituyentes)                Stretch Armstrong
#
#       price-food  rating
# 173        999.0     NaN
# 1814       999.0     NaN

# %%
maxPizza = dfMi.loc[dfMi['rating'] == dfMi['rating'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                                name                           name-food  \
# 34    Circle K 🛒 (Que Palmas 2 989)              AGUA BONAFONT 1L 2X$19
# 37    Circle K 🛒 (Que Palmas 2 989)           COCA COLA LIGHT PET 600ML
# 43    Circle K 🛒 (Que Palmas 2 989)                       CLAMATO 946ML
# 46    Circle K 🛒 (Que Palmas 2 989)            JUGO MANZANA JUMEX 450ML
# 52    Circle K 🛒 (Que Palmas 2 989)  CACAHUATE HOLANDÉS CIRCLE K 105 GR
# ...                             ...                                 ...
# 4272  Circle K 🛒 (Que Palmas 2 989)    JUGO DURAZNO PET DEL VALLE 500ML
# 4296  Circle K 🛒 (Que Palmas 2 989)         CHOKIS CHOCOMAX GAMESA 90GR
# 4323  Circle K 🛒 (Que Palmas 2 989)              SPIRRONES BARCEL 60 GR
# 4336  Circle K 🛒 (Que Palmas 2 989)      MARUCHAN CAMARON C/PIQUIN 1PZA
# 4347  Circle K 🛒 (Que Palmas 2 989)          SANGRIA SENORIAL PET 600ML
#
#       price-food  rating
# 34          19.0     4.9
# ...

# %%
import matplotlib.pyplot as plt
plt.subplot(1,2,1)
plt.plot(dfMi['price-food'],'ro')

plt.subplot(1,2,2)
plt.plot(dfMi['rating'], dfMi['evals'],'ro')

plt.show()

# %%
# Get all "Juriquilla" dataframes
dfJu = df[df['colonia'].str.contains("Juriquilla", na=False, case=False)]
dfJu.reset_index(drop=True, inplace=True)
# dfAlamos.loc[:,['name','name-food','price-food','colonia']]
modeJu = dfJu.loc[df['name-food'] == dfJu['name-food'].mode()[0]]

print('The pizzas with the mode price are:')
modeJu.loc[:,['name','name-food','price-food','colonia','rating','evals']]
# Out:
# The pizzas with the mode price are:
#                                        name              name-food  \
# 123                    El Rincón Del Antojo      Pizza de peperoni
# 377                      Sushi Roll (Antea)  Teppanyaki de Camarón
# 517                         Petit mounchies         YUMMY SURPRISE
# 918                        La Bocha Nautica                Alfajor
# 1331                     Biotica  Querétaro     Waffle de Proteína
# 1383  Experiencia Gourmet Liverpool (Antea)      Refrescos de Lata
# 2169            Todo Empanadas Juriquilla 2               Chipotle
# 2406                        L' Ostería Totó       Picaña a la Leña
# 3926              Sofia Pizzeria El Refugio                 Rucola
# 4186                              Piu Pizza         Pizza con Atún
#
#       price-food     colonia  rating evals
# 123         89.0  juriquilla     NaN   NaN
# 377        307.0  juriquilla     4.5  -304
# 517        720.0  juriquilla     NaN   NaN
# ...

# %%
minPizza = dfJu.loc[dfJu['price-food'] == dfJu['price-food'].min()]

print('The pizzas with the greatest price are:')
minPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                          name         name-food  price-food  rating
# 2271  Fussion Maya Juriquilla  Lechon  Yucateco         0.0     NaN
# 3331  Fussion Maya Juriquilla   Cochinita pibil         0.0     NaN

# %%
maxPizza = dfJu.loc[dfJu['price-food'] == dfJu['price-food'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                            name                   name-food  price-food  \
# 1047           La Bocha Nautica  Bife de Chorizo 600 Gramos       990.0
# 3347  Wohoo! Desayunos Sorpresa                   Lunch box       990.0
#
#       rating
# 1047     4.8
# 3347     NaN

# %%
maxPizza = dfJu.loc[dfJu['rating'] == dfJu['rating'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                             name             name-food  price-food  rating
# 3810  Ge Vito's Pizza Juriquilla            7up 600 ml        20.0     5.0
# 3894  Ge Vito's Pizza Juriquilla       Papas Horneadas        40.0     5.0
# 4008  Ge Vito's Pizza Juriquilla          Pepsi 600 ml        20.0     5.0
# 4341  Ge Vito's Pizza Juriquilla  Manzanita Sol 600 ml        20.0     5.0

# %%
import matplotlib.pyplot as plt
plt.subplot(1,2,1)
plt.plot(dfJu['price-food'],'ro')

plt.subplot(1,2,2)
plt.plot(dfJu['rating'], dfJu['evals'],'ro')

plt.show()

# %%
# Get all "Pueblito" dataframes
dfPu = df[df['colonia'].str.contains("Pueblito", na=False, case=False)]
dfPu.reset_index(drop=True, inplace=True)
# dfAlamos.loc[:,['name','name-food','price-food','colonia']]
modePu = dfPu.loc[df['name-food'] == dfPu['name-food'].mode()[0]]

print('The pizzas with the mode price are:')
modePu.loc[:,['name','name-food','price-food','colonia','rating','evals']]
# Out:
# The pizzas with the mode price are:
#                               name                   name-food  price-food  \
# 13       Rock n’ Pizza Corregidora                     Combo 4        85.0
# 37            Boyos Pizza Candiles      Pizza Alambre Familiar       209.0
# 48          La Campana Café Bistro             Huevos al gusto       129.0
# 936   Todo Empanadas (Corregidora)                    Seven Up        22.0
# 1301               Subway (Tejeda)  Combo Jamón de Cerdo 15 cm        98.0
# 1613   Sushi Roll (Constituyentes)      Ensalada Seaweed Salad       136.0
# 1919                   Benedetti's                   Pepsi 2 L        64.0
# 2322                  Pizza & More              Pizza Hawaiana       169.0
# 2378            Mi Piace Pizza Qro  Piña con Naranja (1 Litro)        45.0
# 2523         La Neta Alas y Chelas            Jocho con Tocino       145.0
#
#        colonia  rating evals
# 13    pueblito     NaN   NaN
# 37    pueblito     4.7  -391
# ...

# %%
minPizza = dfPu.loc[dfPu['price-food'] == dfPu['price-food'].min()]

print('The pizzas with the greatest price are:')
minPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                                     name                   name-food  \
# 134  La Campana Café & Bistro Las Trojes    Coca-Cola light (355 ml)
# 326  La Campana Café & Bistro Las Trojes  Coca-Cola regular (355 ml)
#
#      price-food  rating
# 134         0.0     4.5
# 326         0.0     4.5

# %%
maxPizza = dfPu.loc[dfPu['price-food'] == dfPu['price-food'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#             name            name-food  price-food  rating
# 926  La Tertulia  Spaghetti Bolognesa       900.0     NaN

# %%
maxPizza = dfPu.loc[dfPu['rating'] == dfPu['rating'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                 name                                   name-food  price-food  \
# 71    PANDINIS PIZZA                Pizza Especial Tamaño Grande       198.0
# 129   PANDINIS PIZZA               Pizza Combinada Tamaño Grande       159.0
# 172   PANDINIS PIZZA    Pizza Especial Vegetariana Tamaño Grande       198.0
# 284   PANDINIS PIZZA      Pizza Carnivora Especial Tamaño Grande       198.0
# 299   PANDINIS PIZZA    Pizza Carnivora Especial Tamaño Personal       198.0
# 340   PANDINIS PIZZA                                       Fanta        30.0
# 418   PANDINIS PIZZA                Pizza Básica Tamaño Personal        69.0
# 470   PANDINIS PIZZA              Pizza Especial Tamaño Personal        89.0
# 559   PANDINIS PIZZA       Pizza Hawaiana Especial Tamaño Grande       198.0
# 574   PANDINIS PIZZA                                     Calzone       119.0
# 584   PANDINIS PIZZA             Pizza Combinada Tamaño Personal        79.0
# ...

# %%
import matplotlib.pyplot as plt
plt.subplot(1,2,1)
plt.plot(dfPu['price-food'],'ro')

plt.subplot(1,2,2)
plt.plot(dfPu['rating'], dfPu['evals'],'ro')

plt.show()

# %%
# Get all "cimatario" dataframes
dfCi = df[df['colonia'].str.contains("cimatario", na=False, case=False)]
dfCi.reset_index(drop=True, inplace=True)
# dfAlamos.loc[:,['name','name-food','price-food','colonia']]
modeCi = dfCi.loc[df['name-food'] == dfCi['name-food'].mode()[0]]

print('The pizzas with the mode price are:')
modeCi.loc[:,['name','name-food','price-food','colonia','rating','evals']]
# Out:
# The pizzas with the mode price are:
#                                             name  \
# 13                          El Rincon del Jaguar
# 37    Los Hijos del Che (Hamburguesas al Carbon)
# 48                                  Il Pizzaiolo
# 936                  Sushi Roll (Punta Victoria)
# 1301                                     Di Vino
# 1613                       El Barrio de la Bocha
# 1919                                     Di Vino
# 2322                 Sushi Roll (Punta Victoria)
# 2378                                Napoli Pizza
# 2523                                   Ké-Pizzas
# 2668                                 College Bar
# 2693                                     Pick-Za
# 2724              La Piccola Trattoria Querétaro
# 2784                       Micaela Cocina & Café
# 2875                                 Sinatra 351
# 3280                                     Nambila
# 3510                      Diktatur (Universidad)
# ...

# %%
minPizza = dfCi.loc[dfCi['price-food'] == dfCi['price-food'].min()]

print('The pizzas with the greatest price are:')
minPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                                   name                             name-food  \
# 3971  Nuriko Sushi Express Tecnológico  ¿Para cuántas personas es tu pedido?
#
#       price-food  rating
# 3971        0.01     4.7

# %%
maxPizza = dfCi.loc[dfCi['price-food'] == dfCi['price-food'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#             name              name-food  price-food  rating
# 1835  Don Carbón  PARRILLADA DON CARBON       959.0     4.5

# %%
maxPizza = dfCi.loc[dfCi['rating'] == dfCi['rating'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                                                name  \
# 139   Coffee Tree Cinépolis 🛒 (La Victoria Latitud)
# 160                             Diktatur (Guerrero)
# 167                                       Ké-Pizzas
# 200                             Diktatur (Guerrero)
# 203   Coffee Tree Cinépolis 🛒 (La Victoria Latitud)
# ...                                             ...
# 4752                            Diktatur (Guerrero)
# 4790                                      Ké-Pizzas
# 4815                            Diktatur (Guerrero)
# 4830  Coffee Tree Cinépolis 🛒 (La Victoria Latitud)
# 4863  Coffee Tree Cinépolis 🛒 (La Victoria Latitud)
#
#                        name-food  price-food  rating
# 139       Frappé Cookies & Cream        74.0     4.9
# 160                  Fungi Norte        60.0     4.9
# 167      Pizza Hawaiana Especial        96.0     4.9
# 200              Arroz con leche        60.0     4.9
# ...

# %%
import matplotlib.pyplot as plt
plt.subplot(1,2,1)
plt.plot(dfCi['price-food'],'ro')

plt.subplot(1,2,2)
plt.plot(dfCi['rating'], dfCi['evals'],'ro')

plt.show()

# %%
# Get all "campanario" dataframes
dfCa = df[df['colonia'].str.contains("campanario", na=False, case=False)]
dfCa.reset_index(drop=True, inplace=True)
# dfAlamos.loc[:,['name','name-food','price-food','colonia']]
modeCa = dfCa.loc[df['name-food'] == dfCa['name-food'].mode()[0]]

print('The pizzas with the mode price are:')
modeCa.loc[:,['name','name-food','price-food','colonia','rating','evals']]
# Out:
# The pizzas with the mode price are:
#                                name                               name-food  \
# 13                            Gab’s                        Pizza Chaikovski
# 37                Filemón Querétaro                    Ron Appleton Special
# 48    Tacos Pampas (Constituyentes)                        Volcán arrachera
# 936   Tacos Pampas (Constituyentes)                      Ensalada de salmón
# 1301        La piccola italia arcos                 Pizza La Piccola Italia
# 1613       Pepe Pastes Plaza Master                 Empanada de Champiñones
# 1919        Mi Tiendita Vegetariana                      Milanesa de Quinoa
# 2322              Filemón Querétaro       Whisky Johnnie Walker Black Label
# 2378                  Piccolo Pizza                                   Fanta
# 2523           La Marmota (Mirador)                      Orden de 30 Alitas
# 2668             Diktatur (Peralta)                Agua de guayaba (450 ml)
# ...

# %%
minPizza = dfCa.loc[dfCa['price-food'] == dfCa['price-food'].min()]

print('The pizzas with the greatest price are:')
minPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                  name name-food  price-food  rating
# 52    Pizzeta (Arcos)  Cilantro         5.0     4.3
# 1472  Pizzeta (Arcos)   Pizzeta         5.0     4.3
# 1667  Pizzeta (Arcos)     Ranch         5.0     4.3

# %%
maxPizza = dfCa.loc[dfCa['price-food'] == dfCa['price-food'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#          name              name-food  price-food  rating
# 948  La Bocha  Rib Eye Calidad Prime       945.0     4.7

# %%
maxPizza = dfCa.loc[dfCa['rating'] == dfCa['rating'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                      name                        name-food  price-food  rating
# 22    Dozzo Coffee & Eats                      Oreo frappe        70.0     4.9
# 102   Dozzo Coffee & Eats                 Chocolate frappe        65.0     4.9
# 205   Dozzo Coffee & Eats                          Galleta        20.0     4.9
# 240   Dozzo Coffee & Eats  tisana de frutos rojos caliente        70.0     4.9
# 253   Dozzo Coffee & Eats                        chai frió        70.0     4.9
# ...                   ...                              ...         ...     ...
# 2547  Dozzo Coffee & Eats                            Mixta       125.0     4.9
# 2589  Dozzo Coffee & Eats               Malteada chocolate        65.0     4.9
# 2615  Dozzo Coffee & Eats                   Bisquet salado        65.0     4.9
# 2660  Dozzo Coffee & Eats          Botella de agua natural        20.0     4.9
# ...

# %%
import matplotlib.pyplot as plt
plt.subplot(1,2,1)
plt.plot(dfCa['price-food'],'ro')

plt.subplot(1,2,2)
plt.plot(dfCa['rating'], dfCa['evals'],'ro')

plt.show()

# %%
# Get all "cerritocolorado" dataframes
dfCc = df[df['colonia'].str.contains("cerrito colorado", na=False, case=False)]
dfCc.reset_index(drop=True, inplace=True)
# dfAlamos.loc[:,['name','name-food','price-food','colonia']]
modeCc = dfCc.loc[df['name-food'] == dfCc['name-food'].mode()[0]]

print('The pizzas with the mode price are:')
modeCc.loc[:,['name','name-food','price-food','colonia','rating','evals']]
# Out:
# The pizzas with the mode price are:
#                               name                       name-food  \
# 13        Subway (Pza Sendero QRO)                   Una Probadita
# 37    Nuriko Sushi Express Sendero   Gohan Tampico, Chipotle o Koi
# 48              Tato's Pan y Pizza  Bollos de pan para hamburguesa
# 936             Pizzeria L' Strega                       Paquete 3
# 1301  Nuriko Sushi Express Sendero                        Futomaki
# 1613             Bastard Queretaro                       Naranjada
# 1919     Mr. Biker's Wings & Pizza                         Combo 1
# 2322                Toreto's Pizza                Pizza Grande Tej
# 2378                Tonino´s Pizza                              Té
#
#       price-food           colonia  rating            evals
# 13          18.0  cerrito colorado     NaN  Acompañamientos
# 37          60.0  cerrito colorado     NaN             -158
# 48          30.0  cerrito colorado     NaN              NaN
# ...

# %%
minPizza = dfCc.loc[dfCc['price-food'] == dfCc['price-food'].min()]

print('The pizzas with the greatest price are:')
minPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                  name       name-food  price-food  rating
# 150   Las Gordibuenas      2 Heineken         0.0     NaN
# 1173  Las Gordibuenas         2 Ultra         0.0     NaN
# 1731  Las Gordibuenas  2 Tecate Light         0.0     NaN

# %%
maxPizza = dfCc.loc[dfCc['price-food'] == dfCc['price-food'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                                  name   name-food  price-food  rating
# 2105                Bastard Queretaro  Centenario       799.0     NaN
# 2250  Bastard Pizzas Burgers N Shakes  Centenario       799.0     NaN

# %%
maxPizza = dfCc.loc[dfCc['rating'] == dfCc['rating'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                 name                              name-food  price-food  \
# 2208  Toreto's Pizza  Refresco Caballito Mandarina 1.5 Ltrs        25.0
# 2211  Toreto's Pizza    Pizza Familiar Especialidad Toretos       159.0
# 2228  Toreto's Pizza                     Pizza Grande Hobbs       139.0
# 2231  Toreto's Pizza                Pizza Grande Román Pirs       139.0
# 2240  Toreto's Pizza        Pizza Grande con un Ingrediente       119.0
# ...              ...                                    ...         ...
# 2471  Toreto's Pizza         Pizza Personal Brayan Especial        45.0
# 2478  Toreto's Pizza                     Pizza Familiar Lan       159.0
# 2479  Toreto's Pizza                      Pizza Mediana Han       110.0
# 2493  Toreto's Pizza                 Refresco Squirt 400 ML        15.0
# 2495  Toreto's Pizza                   Pizza Personal Elena        45.0
#
#       rating
# 2208     4.6
# 2211     4.6
# 2228     4.6
# ...

# %%
import matplotlib.pyplot as plt
plt.subplot(1,2,1)
plt.plot(dfCc['price-food'],'ro')

plt.subplot(1,2,2)
plt.plot(dfCc['rating'],'ro')

plt.show()

# %%
# Get all "balvanera" dataframes
dfBa = df[df['colonia'].str.contains("balvanera", na=False, case=False)]
dfBa.reset_index(drop=True, inplace=True)
# dfAlamos.loc[:,['name','name-food','price-food','colonia']]
modeBa = dfBa.loc[df['name-food'] == dfBa['name-food'].mode()[0]]

print('The pizzas with the mode price are:')
modeBa.loc[:,['name','name-food','price-food','colonia','rating','evals']]
# Out:
# The pizzas with the mode price are:
#                             name             name-food  price-food    colonia  \
# 159  El Globo Citadina Querétaro    Pastel Chocrocante        46.0  balvanera
# 419             Piacere Italiano  Carpaccio di Salmone       170.0  balvanera
# 445       La Campana Café Bistro             Café moka        79.0  balvanera
# 927   Nápoles Artesanal Pizzería        Pizza Hawaiana       192.0  balvanera
#
#      rating evals
# 159     4.8  -497
# 419     4.4   -99
# 445     NaN   NaN
# 927     NaN   NaN

# %%
minPizza = dfBa.loc[dfBa['price-food'] == dfBa['price-food'].min()]

print('The pizzas with the greatest price are:')
minPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                                     name                   name-food  \
# 142  La Campana Café & Bistro Las Trojes  Coca-Cola regular (355 ml)
# 675  La Campana Café & Bistro Las Trojes    Coca-Cola light (355 ml)
#
#      price-food  rating
# 142         0.0     4.5
# 675         0.0     4.5

# %%
maxPizza = dfBa.loc[dfBa['price-food'] == dfBa['price-food'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#             name            name-food  price-food  rating
# 727  La Tertulia  Spaghetti Bolognesa       900.0     NaN

# %%
maxPizza = dfBa.loc[dfBa['rating'] == dfBa['rating'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food','rating']]
# Out:
# The pizzas with the greatest price are:
#                name                                   name-food  price-food  \
# 12   PANDINIS PIZZA       Pizza Hawaiana Especial Tamaño Grande       198.0
# 15   PANDINIS PIZZA                                     Calzone       119.0
# 22   PANDINIS PIZZA                  Pizza Básica Tamaño Grande       129.0
# 35   PANDINIS PIZZA      Pizza Carnivora Especial Tamaño Grande       198.0
# 88   PANDINIS PIZZA                                      Sidral        30.0
# 113  PANDINIS PIZZA  Pizza Especial Vegetariana Tamaño Personal        89.0
# 125  PANDINIS PIZZA               Pizza Combinada Tamaño Grande       159.0
# 282  PANDINIS PIZZA             Pizza Combinada Tamaño Personal        79.0
# 338  PANDINIS PIZZA    Pizza Especial Vegetariana Tamaño Grande       198.0
# 353  PANDINIS PIZZA                                Papas Fritas        44.0
# 381  PANDINIS PIZZA                Pizza Básica Tamaño Personal        69.0
# ...

# %%
import matplotlib.pyplot as plt
plt.subplot(1,2,1)
plt.plot(dfBa['price-food'],'ro')

plt.subplot(1,2,2)
plt.plot(dfBa['rating'], dfBa['evals'],'ro')

plt.show()

# %%
meanPizzaCe = dfCentro['price-food'].mean()
print(f'Precio promedio en el centro ${meanPizzaCe}')
meanPizzaRe = dfRe['price-food'].mean()
print(f'Precio promedio en el Refugio ${meanPizzaRe}')
meanPizzaMi = dfMi['price-food'].mean()
print(f'Precio promedio en Milenio ${meanPizzaMi}')
meanPizzaJu = dfJu['price-food'].mean()
print(f'Precio Promedio en Juriquilla ${meanPizzaJu}')
meanPizzaPu = dfPu['price-food'].mean()
print(f'Precio promedio en el pueblito ${meanPizzaPu}')
meanPizzaCi = dfCi['price-food'].mean()
print(f'Precio promedio en el cimatario ${meanPizzaCi}')
meanPizzaCc = dfCc['price-food'].mean()
print(f'Precio promedio en el Cerrito colorado ${meanPizzaCc}')
meanPizzaCa = dfCa['price-food'].mean()
print(f'Precio promedio en el campanario ${meanPizzaCa}')
meanPizzaBa = dfBa['price-food'].mean()
print(f'Precio promedio en Balvanera ${meanPizzaBa}')
meanPizzaAlamos = dfAlamos['price-food'].mean()
print(f'Precio promedio en Alamos ${meanPizzaAlamos}')
# Out:
# Precio promedio en el centro $148.68555889328061
# Precio promedio en el Refugio $139.66769578313253
# Precio promedio en Milenio $129.43395070422534
# Precio Promedio en Juriquilla $131.65709811146937
# Precio promedio en el pueblito $127.5461479494059
# Precio promedio en el cimatario $136.6540871723282
# Precio promedio en el Cerrito colorado $124.1014481645825
# Precio promedio en el campanario $136.7587635239567
# Precio promedio en Balvanera $122.05173041894352
# Precio promedio en Alamos $128.6922650556195

# %%
import matplotlib.pyplot as plt1
plt1.barh(['Alamos','Refugio','Milenio', 'Juriquilla', 'Pueblito', 'Cimatario', 'CerritoC','Campanario','Balvanera', 'Cento'],
       [meanPizzaAlamos,meanPizzaRe,meanPizzaMi,meanPizzaJu,meanPizzaPu,meanPizzaCi,meanPizzaCc,meanPizzaCa,meanPizzaBa,meanPizzaCe])
# Out:
# <BarContainer object of 10 artists>
